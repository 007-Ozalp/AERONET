# %%
import pandas as pd

# %%
import read_aeronet as an

# %%
#FILE NAME DEFINED IN AERONET

RawDataFileName = "./20220101_20221231_Apulian_Tavoliere.lev10"

# %%
k=an.read_aeronet(RawDataFileName)
# Out:
# C:\Users\ozle_\Desktop\aeronet\read_aeronet.py:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, "%d:%m:%Y %H:%M:%S")

# %%
k
# Out:
#                      AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  \
# Date_and_Time
# 2022-01-01 10:01:50      -999.0    0.030062   0.038118     -999.0     -999.0
# 2022-01-01 10:07:54      -999.0    0.024824   0.032342     -999.0     -999.0
# 2022-01-01 10:16:48      -999.0    0.018606   0.025028     -999.0     -999.0
# 2022-01-01 10:31:50      -999.0    0.013301   0.017675     -999.0     -999.0
# 2022-01-01 10:46:49      -999.0    0.014354   0.019258     -999.0     -999.0
# ...                         ...         ...        ...        ...        ...
# 2022-09-22 08:07:01      -999.0    0.028121   0.033213     -999.0     -999.0
# 2022-09-22 08:22:02      -999.0    0.030816   0.036635     -999.0     -999.0
# 2022-09-22 08:37:02      -999.0    0.030644   0.036639     -999.0     -999.0
# 2022-09-22 08:52:03      -999.0    0.029488   0.035332     -999.0     -999.0
# 2022-09-22 08:58:04      -999.0    0.033888   0.039751     -999.0     -999.0
#
# ...

# %%
k.to_csv('aeronet_puglia_apulian_tav_2022.csv')
